# %% [markdown]
# # Signal Analysis Report
#
# ## 調査設計
#
# ### 目的
# {調査で答えたい問いをここに記述}
#
# ### 初期仮説（データを見る前に）
# 1. {仮説1}
# 2. {仮説2}
#
# ### データ
# | ファイル | 条件 | 備考 |
# |---------|------|------|
# | file_a.wav | {条件A} | {備考} |
# | file_b.wav | {条件B} | {備考} |

# %%
import wandas as wd
import numpy as np
import matplotlib.pyplot as plt

# === データ読み込み ===
# signal_a = wd.read_wav('file_a.wav')
# signal_b = wd.read_wav('file_b.wav')

# === Diagnostician: 信号品質確認 ===
# signal_a.info()
# signal_b.info()
# print(f'Clipping check A: {np.max(np.abs(signal_a.data)):.4f}')
# print(f'DC offset A: {np.mean(signal_a.data):.6f}')

# %% [markdown]
# ## Round 1: {ラウンドの見出し}
#
# **動機**: {初期仮説 or 前ラウンドの示唆から}
# **問い**: {このラウンドで答えること}

# %%
# Round 1 解析コード（Analysis Agent から取得）

# %%
# 数値サマリー
# print(f'Key metric: {value:.2f}')

# %% [markdown]
# ### Findings
#
# **観察**: {グラフ・数値から読めること}
#
# **解釈**: {なぜそうなっているか}
#
# **示唆**: {次に調べるべきこと}

# %% [markdown]
# ## 統合考察
#
# ### 仮説検証
# {Synthesis Agent の出力をここに貼る}
#
# ### 主要な結論
# 1. {結論1}
# 2. {結論2}
#
# ### 次のステップ
# {推奨する追加調査}
#
# ### 未解決の問い
# {答えられなかった問い}

# %%
# 全指標サマリーテーブル・条件間比較
# import pandas as pd
# summary = pd.DataFrame({
#     '指標': ['Leq dB(A)', 'Loudness sone', ...],
#     '条件A': [...],
#     '条件B': [...],
#     '差分': [...]
# })
# print(summary.to_string(index=False))
